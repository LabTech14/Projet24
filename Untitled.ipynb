# %%
import pandas as pd

# Data from Part 1 provided in the message
data_part1 = {
    "MOVIE": ["Batman Forever", "Independence Day", "Men in Black", "Titanic",
              "Star Wars Ep. I: The Phantom Menace", "How the Grinch Stole Christmas",
              "Harry Potter and the Sorcerer’s Stone", "Spider-Man", "Finding Nemo",
              "Shrek 2", "Star Wars Ep. III: Revenge of the Sith",
              "Pirates of the Caribbean: Dead Man’s Chest", "Spider-Man 3",
              "The Dark Knight", "Transformers: Revenge of the Fallen", "Toy Story 3"],
    "GENRE": ["Drama", "Adventure", "Adventure", "Adventure",
              "Adventure", "Adventure", "Adventure", "Adventure",
              "Adventure", "Adventure", "Action", "Action", "Adventure",
              "Adventure", "Action", "Action"],
    "juil-21": [259311, 14506, 2251, 81641, 1506, 1296, 7586, 1246,
                544951, 1271, 1246, 5746, 1246, 1246, 908851, 1246],
    "août-21": [263611, 18876, 2286, 86581, 1501, 1296, 7081, 1246,
                576636, 1271, 1246, 5816, 1246, 1246, 953741, 1246],
    "sept-21": [263801, 8641, 2286, 78091, 1501, 1296, 8006, 1246,
                564851, 1271, 1246, 5836, 1246, 1246, 924366, 1246],
    "oct-21": [279256, 5236, 3756, 92076, 1516, 1291, 12296, 1246,
               516416, 1271, 1246, 5671, 1251, 1246, 907576, 1246],
    "nov-21": [283426, 5066, 4451, 94381, 1501, 1296, 1246, 1246,
               558496, 1271, 1246, 5841, 1256, 1246, 945771, 1246],
    "déc-21": [590476, 2286, 4956, 187256, 1746, 1346, 1246, 1246,
               1139066, 1276, 1246, 10066, 1396, 1246, 1928656, 1246],
    "janv-22": [300861, 1316, 2671, 111241, 1496, 1296, 1246, 1246,
                606996, 1246, 1246, 5821, 1256, 1291, 1023031, 1246]
}

# Data from Part 2 provided in the message
data_part2 = {
    "MOVIE": ["Batman Forever", "Independence Day", "Men in Black", "Titanic",
              "Star Wars Ep. I: The Phantom Menace", "How the Grinch Stole Christmas",
              "Harry Potter and the Sorcerer’s Stone", "Spider-Man", "Finding Nemo",
              "Shrek 2", "Star Wars Ep. III: Revenge of the Sith",
              "Pirates of the Caribbean: Dead Man’s Chest", "Spider-Man 3",
              "The Dark Knight", "Transformers: Revenge of the Fallen", "Toy Story 3"],
    "DISTRIBUTOR": ["Warner Bros.", "20th Century Fox", "Sony Pictures", "Paramount Pictures",
                    "20th Century Fox", "Universal", "Warner Bros.", "Sony Pictures",
                    "Walt Disney", "Dreamworks SKG", "20th Century Fox", "Walt Disney",
                    "Sony Pictures", "Warner Bros.", "Paramount Pictures", "Walt Disney"]
}

# Creating DataFrames
df_part1 = pd.DataFrame(data_part1)
df_part2 = pd.DataFrame(data_part2)

# Display the DataFrames to ensure they are correct
df_part1.head(), df_part2.head()
# Out:
# (                                 MOVIE      GENRE  juil-21  août-21  sept-21  \
#  0                       Batman Forever      Drama   259311   263611   263801
#  1                     Independence Day  Adventure    14506    18876     8641
#  2                         Men in Black  Adventure     2251     2286     2286
#  3                              Titanic  Adventure    81641    86581    78091
#  4  Star Wars Ep. I: The Phantom Menace  Adventure     1506     1501     1501
#
#     oct-21  nov-21  déc-21  janv-22
#  0  279256  283426  590476   300861
#  1    5236    5066    2286     1316
#  2    3756    4451    4956     2671
#  3   92076   94381  187256   111241
#  4    1516    1501    1746     1496  ,
#                                   MOVIE         DISTRIBUTOR
#  0                       Batman Forever        Warner Bros.
#  1                     Independence Day    20th Century Fox
#  2                         Men in Black       Sony Pictures
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Assuming 'df' has movies in the rows and months in the columns as per your image
# Task 2: Create Column and Raw totals
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df.loc['Total'] = df.iloc[:, 2:].sum()

# Task 3: Create an Average, Min and Max column
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)

# Task 4: Create a month over month column for the latest month
# Assuming that the last month is 'janv-22' and the second last is 'déc-21'
#df['MoM'] = (df['janv-22'] - df['déc-21']) / df['déc-21']
# Using the datetime objects directly as column names
df['MoM'] = (df[pd.Timestamp('2022-01-01')] - df[pd.Timestamp('2021-12-01')]) / df[pd.Timestamp('2021-12-01')].replace(0, 1)


# Task 6: Sort the data by Totals; descending
df_sorted = df.sort_values(by='Total', ascending=False)

# Task 7: Create a new column that has “above average” or “below average” text depending on the Total value
average_total = df['Total'].mean()
df['Above/Below Average'] = df['Total'].apply(lambda x: 'Above Average' if x > average_total else 'Below Average')

# Task 8: Join the Distributor from part 2
df = df.merge(distributors, on='MOVIE', how='left')

# Task 9: Create a pivot table for distributors
pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Task 10: Create a horizontal bar chart for totals by Movie
df_sorted.plot(kind='barh', x='MOVIE', y='Total')
plt.show()

# Task 11: Create a vertical bar chart for average value by Genre
df.groupby('GENRE')['Average'].mean().plot(kind='bar')
plt.show()

# Task 12: Create a pie chart for the average value by Distributor
pivot_table_distributors['mean'].plot(kind='pie', y='Total', autopct='%1.1f%%')
plt.show()

# Note: Before running this code, make sure to adjust the column names and calculations according to your actual data.

# %%
print(df.columns)
# Out:
# Index([            'MOVIE',             'GENRE', 2021-07-01 00:00:00,
#        2021-08-01 00:00:00, 2021-09-01 00:00:00, 2021-10-01 00:00:00,
#        2021-11-01 00:00:00, 2021-12-01 00:00:00, 2022-01-01 00:00:00,
#                    'Total',           'Average',               'Min',
#                      'Max'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you've already loaded the DataFrame as df and the distributors as distributors_df
# Load the data
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Task 2: Create Column and Raw totals
df['Total'] = df.iloc[:, 2:-4].sum(axis=1)
df.loc['Row_Total'] = df.iloc[:, 2:-4].sum()

# Task 3: Create an Average, Min and Max column
df['Average'] = df.iloc[:, 2:-5].mean(axis=1)
df['Min'] = df.iloc[:, 2:-6].min(axis=1)
df['Max'] = df.iloc[:, 2:-7].max(axis=1)

# Task 4: Create a month over month column for the latest month
# We use the last and second last month based on your DataFrame
last_month = df.columns[-5]
second_last_month = df.columns[-6]
df['MoM'] = (df[last_month] - df[second_last_month]) / df[second_last_month].replace(0, 1)

# Task 6: Sort the data by Totals; descending
df_sorted = df.sort_values(by='Total', ascending=False)

# Task 7: Create a new column that has “above average” or “below average” text depending on the Total value
average_total = df['Total'].mean()
df['Above/Below Average'] = df['Total'].apply(lambda x: 'Above Average' if x > average_total else 'Below Average')

# Task 8: Join the Distributor from part 2
# Make sure the 'MOVIE' column is set as the index for both DataFrames if not already
df.set_index('MOVIE', inplace=True)
distributors_df.set_index('MOVIE', inplace=True)
df = df.join(distributors_df)

# Task 9: Create a pivot table for distributors
pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Task 10: Create a horizontal bar chart for totals by Movie
df_sorted['Total'].plot(kind='barh', title='Total by Movie')
plt.show()

# Task 11: Create a vertical bar chart for average value by Genre
df.groupby('GENRE')['Average'].mean().plot(kind='bar', title='Average Value by Genre')
plt.show()

# Task 12: Create a pie chart for the average value by Distributor
pivot_table_distributors['mean']['Total'].plot(kind='pie', autopct='%1.1f%%', title='Average Value by Distributor')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 34
#      31 # Task 8: Join the Distributor from part 2
#      32 # Make sure the 'MOVIE' column is set as the index for both DataFrames if not already
#      33 df.set_index('MOVIE', inplace=True)
# ---> 34 distributors_df.set_index('MOVIE', inplace=True)
#      35 df = df.join(distributors_df)
#      37 # Task 9: Create a pivot table for distributors
#
# NameError: name 'distributors_df' is not defined

# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Assuming df is your main data DataFrame and distributors_df is your distributors DataFrame
# Let's assume you have already loaded these DataFrames from an Excel file as shown in previous steps
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Create the Pivot Table for distributors
pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Initialize Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='bar-plot-total-by-movie'),
    dcc.Graph(id='bar-plot-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
])

# Define callback to update bar plot for totals by movie
@app.callback(
    Output('bar-plot-total-by-movie', 'figure'),
    [Input('bar-plot-total-by-movie', 'id')]
)
def update_bar_total_by_movie(_):
    fig = px.bar(df_sorted, x='Total', y=df.index, orientation='h')
    fig.update_layout(title='Total Revenue by Movie')
    return fig

# Define callback to update bar plot for average by genre
@app.callback(
    Output('bar-plot-average-by-genre', 'figure'),
    [Input('bar-plot-average-by-genre', 'id')]
)
def update_bar_average_by_genre(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    fig.update_layout(title='Average Revenue by Genre')
    return fig

# Define callback to update pie chart for average by distributor
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_average_by_distributor(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=('mean', 'Total'))
    fig.update_layout(title='Average Revenue by Distributor')
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 14
#      11 distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')
#      13 # Create the Pivot Table for distributors
# ---> 14 pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])
#      16 # Initialize Dash app
#      17 app = dash.Dash(__name__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(
#     self,
#     values,
#     index,
#     columns,
#     aggfunc,
#     fill_value,
#     margins,
#     dropna,
#     margins_name,
#     observed,
#     sort
# )
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
from dash.exceptions import PreventUpdate

# Load the data
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Perform your data manipulations here...

# Task 9: Create a pivot table for distributors
pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    html.Hr(),
    html.Div(id='pivot-table-container')  # Container for pivot table
])

# Callback for horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df_sorted, x='Total', y=df_sorted.index, orientation='h')
    return fig

# Callback for vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=('mean', 'Total'))
    return fig

# Callback for displaying the pivot table as a downloadable link
@app.callback(
    Output('pivot-table-container', 'children'),
    [Input('pivot-table-container', 'id')]
)
def update_pivot_table(_):
    # If you want to show the pivot table directly in the dashboard, convert it to HTML
    # For a large table, it's better to provide a download link
    pivot_html = pivot_table_distributors.to_html()
    return html.Div([html.H3('Pivot Table'), html.Div(pivot_html, style={'overflowX': 'auto'})])

# Run the Dash app on port 5511
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 13
#       8 distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')
#      10 # Perform your data manipulations here...
#      11
#      12 # Task 9: Create a pivot table for distributors
# ---> 13 pivot_table_distributors = df.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])
#      15 # Initialize the Dash app
#      16 app = Dash(__name__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(
#     self,
#     values,
#     index,
#     columns,
#     aggfunc,
#     fill_value,
#     margins,
#     dropna,
#     margins_name,
#     observed,
#     sort
# )
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Assuming the data is already loaded in df and distributors as shown previously

# Load the data into pandas DataFrames
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Perform your data manipulations here...

# Make sure the 'Total' column exists
df['Total'] = df.iloc[:, 2:-4].sum(axis=1)

# Merge the distributor data
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Create the pivot table for distributors
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback for the horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df_sorted, x='Total', y=df_sorted.index, orientation='h')
    return fig

# Callback for the vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for the pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=('mean', 'Total'))
    return fig

# Callback for the scatter plot for MoM change
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_data=['MOVIE'])
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5511/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1961, in DataFrameGroupBy.__getitem__(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     key='Average'
# )
#    1954 if isinstance(key, tuple) and len(key) > 1:
#    1955     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1956     # valid syntax, so don't raise
#    1957     raise ValueError(
#    1958         "Cannot subset columns with a tuple with more than one element. "
#    1959         "Use a list instead."
#    1960     )
# -> 1961 return super().__getitem__(key)
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Assuming the data is already loaded in df and distributors as shown previously

# Load the data into pandas DataFrames
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Perform your data manipulations here...
# Ensure these columns are created and populated correctly.
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)  # Calculate MoM based on the last two columns

# Merge the distributor data
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Create the pivot table for distributors
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Prepare the data for sorting and plotting
df_sorted = df_merged.sort_values(by='Total', ascending=False)

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback for the horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df_sorted, x='Total', y=df_sorted['MOVIE'], orientation='h')
    return fig

# Callback for the vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for the pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=('mean', 'Total'))
    return fig

# Callback for the scatter plot for MoM change
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df_merged, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Run the Dash app on port 5511
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5511/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_chart_types.py:1482, in pie(
#     data_frame=                        sum          mean
#       ...310e+06
# Warner Bros.        2288216  7.627387e+05,
#     names=Index(['20th Century Fox', 'Dreamworks SKG', 'Pa...ros.'],
#       dtype='object', name='DISTRIBUTOR'),
#     values=('mean', 'Total'),
#     color=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     hover_name=None,
#     hover_data=None,
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Assuming the data is already loaded in df and distributors as shown previously

# Load the data into pandas DataFrames
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Perform your data manipulations here...
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)  # Calculate MoM based on the last two columns

# Merge the distributor data
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Create the pivot table for distributors
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Prepare the data for sorting and plotting
df_sorted = df_merged.sort_values(by='Total', ascending=False)

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback for the horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df_sorted, x='Total', y=df_sorted['MOVIE'], orientation='h')
    return fig

# Callback for the vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for the pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    # Choose 'sum' or 'mean' for the values
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=('mean', 'Total')[1])
    return fig

# Callback for the scatter plot for MoM change
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df_merged, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Run the Dash app on port 5511
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5511/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_chart_types.py:1482, in pie(
#     data_frame=                        sum          mean
#       ...310e+06
# Warner Bros.        2288216  7.627387e+05,
#     names=Index(['20th Century Fox', 'Dreamworks SKG', 'Pa...ros.'],
#       dtype='object', name='DISTRIBUTOR'),
#     values='Total',
#     color=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     hover_name=None,
#     hover_data=None,
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Load the data into pandas DataFrames
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Data manipulations
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Merge the distributor data
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Create the pivot table for distributors
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback for the horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

# Callback for the vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for the pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    value_column = ('sum', 'Total')  # or ('mean', 'Total') for average
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values=value_column)
    return fig

# Callback for the scatter plot for MoM change
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Run the Dash app on port 5511
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_chart_types.py:1482, in pie(
#     data_frame=                        sum          mean
#       ...310e+06
# Warner Bros.        2288216  7.627387e+05,
#     names=Index(['20th Century Fox', 'Dreamworks SKG', 'Pa...ros.'],
#       dtype='object', name='DISTRIBUTOR'),
#     values=('mean', 'Total'),
#     color=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     category_orders=None,
#     labels=None,
#     title=None,
#     template=None,
#     width=None,
#     height=None,
#     opacity=None,
#     hole=None
# )
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Load the data into pandas DataFrames
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Data manipulations
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Merge the distributor data
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Create the pivot table for distributors
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Flatten the MultiIndex for easier access in Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback for the horizontal bar chart
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

# Callback for the vertical bar chart
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback for the pie chart
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')  # or 'mean_Total'
    return fig

# Callback for the scatter plot for MoM change
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True, port=5511)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5511/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
import dash_table
from dash import Dash, dcc, html, Input, Output

# Load the data
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Data manipulations
# ... [same as previous code] ...

# Pivot table
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialize the Dash app
app = Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1('Movie Data Dashboard', style={'textAlign': 'center'}),
    html.Div([
        html.Div([dcc.Graph(id='horizontal-bar-total-by-movie')], style={'width': '50%'}),
        html.Div([dcc.Graph(id='vertical-bar-average-by-genre')], style={'width': '50%'})
    ], style={'display': 'flex'}),
    html.Div([
        html.Div([dcc.Graph(id='pie-chart-average-by-distributor')], style={'width': '50%'}),
        html.Div([dcc.Graph(id='scatter-mom-change')], style={'width': '50%'})
    ], style={'display': 'flex'}),
    html.Div([
        dash_table.DataTable(
            data=pivot_table_distributors.reset_index().to_dict('records'),
            columns=[{'name': i, 'id': i} for i in pivot_table_distributors.reset_index().columns],
            style_table={'overflowX': 'auto'}
        )
    ], style={'padding': '20px'})
])

# Callbacks for the graphs
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    fig.update_layout(title='Total by Movie')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    fig.update_layout(title='Average by Genre')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')  # or 'mean_Total'
    fig.update_layout(title='Average by Distributor')
    return fig

@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    fig.update_layout(title='Month-over-Month Change')
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True, port=5512)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5512/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1961, in DataFrameGroupBy.__getitem__(
#     self=<pandas.core.groupby.generic.DataFrameGroupBy object>,
#     key='Average'
# )
#    1954 if isinstance(key, tuple) and len(key) > 1:
#    1955     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1956     # valid syntax, so don't raise
#    1957     raise ValueError(
#    1958         "Cannot subset columns with a tuple with more than one element. "
#    1959         "Use a list instead."
#    1960     )
# -> 1961 return super().__getitem__(key)
# ...

# %%
print(df.head())
# Out:
#                                  MOVIE      GENRE  2021-07-01 00:00:00  \
# 0                       Batman Forever      Drama               259311
# 1                     Independence Day  Adventure                14506
# 2                         Men in Black  Adventure                 2251
# 3                              Titanic  Adventure                81641
# 4  Star Wars Ep. I: The Phantom Menace  Adventure                 1506
#
#    2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 0               263611               263801               279256
# 1                18876                 8641                 5236
# 2                 2286                 2286                 3756
# 3                86581                78091                92076
# 4                 1501                 1501                 1516
#
#    2021-11-01 00:00:00  2021-12-01 00:00:00  2022-01-01 00:00:00
# 0               283426               590476               300861
# ...

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# Charger les données dans des DataFrames pandas
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner les données de distributeur
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Créer le tableau croisé dynamique pour les distributeurs
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Aplatir l'index MultiIndex pour un accès plus facile dans Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialiser l'application Dash
app = Dash(__name__)

# Définir la mise en page de l'application
app.layout = html.Div([
    html.H1('Tableau de bord des données des films'),
    dcc.Graph(id='horizontal-bar-total-by-movie'),
    dcc.Graph(id='vertical-bar-average-by-genre'),
    dcc.Graph(id='pie-chart-average-by-distributor'),
    dcc.Graph(id='scatter-mom-change'),
])

# Callback pour le graphique en barres horizontales
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

# Callback pour le graphique en barres verticales
@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

# Callback pour le graphique en camembert
@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')  # ou 'mean_Total'
    return fig

# Callback pour le graphique en nuage de points pour le changement MoM
@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Exécuter l'application Dash
if __name__ == '__main__':
    app.run_server(debug=True, port=5513)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5513/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# [Chargement des données et préparation des DataFrames]

# Charger les données dans des DataFrames pandas
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner les données de distributeur
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Créer le tableau croisé dynamique pour les distributeurs
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Aplatir l'index MultiIndex pour un accès plus facile dans Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialiser l'application Dash
app = Dash(__name__)

# Définir la mise en page de l'application
app.layout = html.Div([
    html.H1('Tableau de bord des données des films', style={'textAlign': 'center'}),
    html.Div([  # Première ligne
        html.Div([  # Première colonne de la première ligne
            dcc.Graph(id='horizontal-bar-total-by-movie')
        ], className='six columns'),

        html.Div([  # Deuxième colonne de la première ligne
            dcc.Graph(id='vertical-bar-average-by-genre')
        ], className='six columns'),
    ], className='row'),

    html.Div([  # Deuxième ligne
        html.Div([  # Première colonne de la deuxième ligne
            dcc.Graph(id='pie-chart-average-by-distributor')
        ], className='six columns'),

        html.Div([  # Deuxième colonne de la deuxième ligne
            dcc.Graph(id='scatter-mom-change')
        ], className='six columns'),
    ], className='row'),
])

# [Callbacks pour mettre à jour les graphiques]

# Exécuter l'application Dash
if __name__ == '__main__':
    app.run_server(debug=True, port=5515)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5515/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc

# Charger les données
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner avec les données des distributeurs
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Table pivot pour les distributeurs
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialiser l'application Dash
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(dcc.Graph(id='horizontal-bar-total-by-movie'), md=6),
        dbc.Col(dcc.Graph(id='vertical-bar-average-by-genre'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='pie-chart-average-by-distributor'), md=6),
        dbc.Col(dcc.Graph(id='scatter-mom-change'), md=6)
    ])
], fluid=True)

# Callbacks pour les graphiques
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')
    return fig

@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Exécuter l'application
if __name__ == '__main__':
    app.run_server(debug=True, port=5515)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5515/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc

# Charger les données
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner avec les données des distributeurs
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Table pivot pour les distributeurs
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Initialiser l'application Dash
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Style CSS pour les encadrements
style_card = {
    'border': '1px solid #007bff',
    'border-radius': '5px',
    'padding': '10px',
    'margin': '10px',
    'text-align': 'center'
}

# Layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(html.Div([
            html.H3("Moyenne"),
            html.H4(f"{df['Total'].mean():.0f}", style={'color': '#007bff'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Maximum"),
            html.H4(f"{df['Total'].max():.0f}", style={'color': '#28a745'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Minimum"),
            html.H4(f"{df['Total'].min():.0f}", style={'color': '#dc3545'})
        ], style=style_card), md=4)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='horizontal-bar-total-by-movie'), md=6),
        dbc.Col(dcc.Graph(id='vertical-bar-average-by-genre'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='pie-chart-average-by-distributor'), md=6),
        dbc.Col(dcc.Graph(id='scatter-mom-change'), md=6)
    ])
], fluid=True)

# Callbacks pour les graphiques
# ... (Les callbacks restent inchangés)
# Callbacks pour les graphiques
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')
    return fig

@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig


# Exécuter l'application
if __name__ == '__main__':
    app.run_server(debug=True, port=5517)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5517/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output, dash_table
import dash_bootstrap_components as dbc

# Charger les données
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner avec les données des distributeurs
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Création du tableau croisé dynamique
pivot_table_distributors = df_merged.pivot_table(
    index='DISTRIBUTOR',  # Spécifiez 'DISTRIBUTOR' comme index
    values='Total',
    aggfunc=['sum', 'mean']
)

# Aplatir le MultiIndex pour un accès plus facile dans Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Arrondir les valeurs à un chiffre après la virgule
pivot_table_distributors = pivot_table_distributors.round(1)

# Réinitialiser l'index pour transformer les index en colonne pour l'affichage dans Plotly
pivot_table_distributors.reset_index(inplace=True)



# Initialiser l'application Dash
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Style CSS pour les encadrements
style_card = {
    'border': '1px solid #007bff',
    'border-radius': '5px',
    'padding': '10px',
    'margin': '10px',
    'text-align': 'center'
}

# Layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(html.Div([
            html.H3("Moyenne"),
            html.H4(f"{df['Total'].mean():.0f}", style={'color': '#007bff'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Maximum"),
            html.H4(f"{df['Total'].max():.0f}", style={'color': '#28a745'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Minimum"),
            html.H4(f"{df['Total'].min():.0f}", style={'color': '#dc3545'})
        ], style=style_card), md=4)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='horizontal-bar-total-by-movie'), md=6),
        dbc.Col(dcc.Graph(id='vertical-bar-average-by-genre'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='pie-chart-average-by-distributor'), md=6),
        dbc.Col(dcc.Graph(id='scatter-mom-change'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dash_table.DataTable(
            data=pivot_table_distributors.reset_index().to_dict('records'),
            columns=[{'name': i, 'id': i} for i in pivot_table_distributors.columns],
            style_table={'overflowX': 'auto'},
            style_cell={
                'height': 'auto',
                'minWidth': '180px', 'width': '180px', 'maxWidth': '180px',
                'whiteSpace': 'normal'
            }
        ), md=12)
    ])
], fluid=True)

# Callbacks pour les graphiques
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
#def update_pie_chart(_):
    #fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')
   # return fig

def update_pie_chart(_):
    # Arrondir les valeurs de somme totale avant de créer le graphique
    pivot_table_distributors['sum_Total_rounded'] = pivot_table_distributors['sum_Total'].round(1)
    fig = px.pie(pivot_table_distributors, names='DISTRIBUTOR', values='sum_Total_rounded')
    
    # Vous pouvez supprimer la colonne arrondie si elle n'est plus nécessaire
    pivot_table_distributors.drop('sum_Total_rounded', axis=1, inplace=True)

    return fig

@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig


# Exécuter l'application
if __name__ == '__main__':
    app.run_server(debug=True, port=5521)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5521/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output, dash_table
import dash_bootstrap_components as dbc

# Charger les données
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner avec les données des distributeurs
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Création du tableau croisé dynamique pour les distributeurs
pivot_table_distributors = df_merged.pivot_table(index='DISTRIBUTOR', values='Total', aggfunc=['sum', 'mean'])

# Aplatir le MultiIndex pour un accès plus facile dans Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Arrondir les valeurs à un chiffre après la virgule
pivot_table_distributors = pivot_table_distributors.round(1)

# Réinitialiser l'index pour transformer les index en colonnes pour l'affichage dans Plotly
pivot_table_distributors.reset_index(inplace=True)

# Initialiser l'application Dash avec des styles Bootstrap
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])


# Style CSS pour les encadrements
style_card = {
    'border': '1px solid #007bff',
    'border-radius': '5px',
    'padding': '10px',
    'margin': '10px',
    'text-align': 'center'
}

# Layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(html.Div([
            html.H3("Moyenne"),
            html.H4(f"{df['Total'].mean():.0f}", style={'color': '#007bff'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Maximum"),
            html.H4(f"{df['Total'].max():.0f}", style={'color': '#28a745'})
        ], style=style_card), md=4),
        dbc.Col(html.Div([
            html.H3("Minimum"),
            html.H4(f"{df['Total'].min():.0f}", style={'color': '#dc3545'})
        ], style=style_card), md=4)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='horizontal-bar-total-by-movie'), md=6),
        dbc.Col(dcc.Graph(id='vertical-bar-average-by-genre'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='pie-chart-average-by-distributor'), md=6),
        dbc.Col(dcc.Graph(id='scatter-mom-change'), md=6)
    ]),
    dbc.Row([
        dbc.Col(dash_table.DataTable(
            data=pivot_table_distributors.reset_index().to_dict('records'),
            columns=[{'name': i, 'id': i} for i in pivot_table_distributors.columns],
            style_table={'overflowX': 'auto'},
            style_cell={
                'height': 'auto',
                'minWidth': '180px', 'width': '180px', 'maxWidth': '180px',
                'whiteSpace': 'normal'
            }
        ), md=12)
    ])
], fluid=True)

# Définition du layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(html.Div([
            dcc.Graph(id='horizontal-bar-total-by-movie'),
        ], style=card_style), md=6),
        dbc.Col(html.Div([
            dcc.Graph(id='vertical-bar-average-by-genre'),
        ], style=card_style), md=6)
    ]),
    dbc.Row([
        dbc.Col(html.Div([
            dcc.Graph(id='pie-chart-average-by-distributor'),
        ], style=card_style), md=6),
        dbc.Col(html.Div([
            dcc.Graph(id='scatter-mom-change'),
        ], style=card_style), md=6)
    ]),
    dbc.Row([
        dbc.Col(dash_table.DataTable(
            data=pivot_table_distributors.to_dict('records'),
            columns=[{'name': i, 'id': i} for i in pivot_table_distributors.columns],
            style_table={'overflowX': 'auto'},
            style_cell={
                'height': 'auto',
                'minWidth': '180px', 'width': '180px', 'maxWidth': '180px',
                'whiteSpace': 'normal'
            },
            style_header={
                'fontWeight': 'bold',
                'backgroundColor': '#f8f9fa'
            }
        ), md=12)
    ])
], fluid=True)

# Callbacks pour les graphiques

@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
#def update_pie_chart(_):
    #fig = px.pie(pivot_table_distributors, names=pivot_table_distributors.index, values='sum_Total')
   # return fig

def update_pie_chart(_):
    # Arrondir les valeurs de somme totale avant de créer le graphique
    pivot_table_distributors['sum_Total_rounded'] = pivot_table_distributors['sum_Total'].round(1)
    fig = px.pie(pivot_table_distributors, names='DISTRIBUTOR', values='sum_Total_rounded')
    
    # Vous pouvez supprimer la colonne arrondie si elle n'est plus nécessaire
    pivot_table_distributors.drop('sum_Total_rounded', axis=1, inplace=True)

    return fig

@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Exécuter l'application
if __name__ == '__main__':
    app.run_server(debug=True, port=8058)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output, dash_table
import dash_bootstrap_components as dbc

# Charger les données
df = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 1')
distributors = pd.read_excel("C:/Users/LP/Desktop/analyst/Data Analysis/Excel Evaluation - Topic.xlsx", sheet_name='Part 2')

# Manipulations de données
df['Total'] = df.iloc[:, 2:].sum(axis=1)
df['Average'] = df.iloc[:, 2:-1].mean(axis=1)
df['Min'] = df.iloc[:, 2:-2].min(axis=1)
df['Max'] = df.iloc[:, 2:-3].max(axis=1)
df['MoM'] = (df.iloc[:, -2] - df.iloc[:, -3]) / df.iloc[:, -3].replace(0, 1)

# Fusionner avec les données des distributeurs
df_merged = df.merge(distributors, on='MOVIE', how='left')

# Création du tableau croisé dynamique
pivot_table_distributors = df_merged.pivot_table(
    index='DISTRIBUTOR', 
    values='Total',
    aggfunc=['sum', 'mean']
)

# Aplatir le MultiIndex pour un accès plus facile dans Plotly
pivot_table_distributors.columns = ['_'.join(col).strip() for col in pivot_table_distributors.columns.values]

# Arrondir les valeurs à un chiffre après la virgule
pivot_table_distributors = pivot_table_distributors.round(1)

# Réinitialiser l'index pour transformer les index en colonne pour l'affichage dans Plotly
pivot_table_distributors.reset_index(inplace=True)

# Initialiser l'application Dash
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Style CSS pour les encadrements des graphiques et des statistiques
card_style = {
    'border': '1px solid #007bff',  # Épaisseur du cadre ajustée à 1px
    'border-radius': '5px',
    'padding': '10px',
    'margin': '10px',
    'text-align': 'center'
}

# Layout de l'application
app.layout = dbc.Container([
    html.H1('Tableau de bord des données cinématographiques'),
    dbc.Row([
        dbc.Col(html.Div([
            html.H3("Moyenne"),
            html.H4(f"{df['Total'].mean():.1f}", style={'color': '#007bff'})
        ], style=card_style), md=4),
        dbc.Col(html.Div([
            html.H3("Maximum"),
            html.H4(f"{df['Total'].max():.1f}", style={'color': '#28a745'})
        ], style=card_style), md=4),
        dbc.Col(html.Div([
            html.H3("Minimum"),
            html.H4(f"{df['Total'].min():.1f}", style={'color': '#dc3545'})
        ], style=card_style), md=4)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='horizontal-bar-total-by-movie', style=card_style), md=6),
        dbc.Col(dcc.Graph(id='vertical-bar-average-by-genre', style=card_style), md=6)
    ]),
    dbc.Row([
        dbc.Col(dcc.Graph(id='pie-chart-average-by-distributor', style=card_style), md=6),
        dbc.Col(dcc.Graph(id='scatter-mom-change', style=card_style), md=6)
    ]),
  

    dbc.Row([
        dbc.Col(dash_table.DataTable(
            data=pivot_table_distributors.to_dict('records'),
            columns=[{'name': i, 'id': i} for i in pivot_table_distributors.columns],
            style_table={'overflowX': 'auto'},
            style_cell={
                'height': 'auto',
                'minWidth': '180px', 'width': '180px', 'maxWidth': '180px',
                'whiteSpace': 'normal'
            },
            style_header={
                'backgroundColor': 'rgb(230, 230, 230)',
                'fontWeight': 'bold'
            },
            style_data_conditional=[
                {
                    'if': {'row_index': 'odd'},
                    'backgroundColor': 'rgb(248, 248, 248)'
                }
            ]
        ), md=12)
    ])
], fluid=True)

# Callbacks pour les graphiques
@app.callback(
    Output('horizontal-bar-total-by-movie', 'figure'),
    [Input('horizontal-bar-total-by-movie', 'id')]
)
def update_horizontal_bar(_):
    fig = px.bar(df, x='Total', y='MOVIE', orientation='h')
    return fig

@app.callback(
    Output('vertical-bar-average-by-genre', 'figure'),
    [Input('vertical-bar-average-by-genre', 'id')]
)
def update_vertical_bar(_):
    avg_by_genre = df.groupby('GENRE')['Average'].mean().reset_index()
    fig = px.bar(avg_by_genre, x='GENRE', y='Average')
    return fig

@app.callback(
    Output('pie-chart-average-by-distributor', 'figure'),
    [Input('pie-chart-average-by-distributor', 'id')]
)
def update_pie_chart(_):
    fig = px.pie(pivot_table_distributors, names='DISTRIBUTOR', values='sum_Total')
    return fig


@app.callback(
    Output('scatter-mom-change', 'figure'),
    [Input('scatter-mom-change', 'id')]
)
def update_scatter_mom_change(_):
    fig = px.scatter(df, x='Total', y='MoM', color='GENRE', size='Total', hover_name='MOVIE')
    return fig

# Exécuter l'application
if __name__ == '__main__':
    app.run_server(debug=True, port=5522)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5522/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Mapping des jours de la semaine de l'anglais vers le français
jours_en_francais = {
    'Monday': 'Lundi',
    'Tuesday': 'Mardi',
    'Wednesday': 'Mercredi',
    'Thursday': 'Jeudi',
    'Friday': 'Vendredi',
    'Saturday': 'Samedi',
    'Sunday': 'Dimanche'
}

# %%
Jour = pd.DtaFrame(jours_en_francais)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Jour = pd.DtaFrame(jours_en_francais)
#
# AttributeError: module 'pandas' has no attribute 'DtaFrame'

# %%
import pandas as pd

# %%
import pandas as pd

# Data from Part 1 provided in the message
data_part1 = {
    "MOVIE": ["Batman Forever", "Independence Day", "Men in Black", "Titanic",
              "Star Wars Ep. I: The Phantom Menace", "How the Grinch Stole Christmas",
              "Harry Potter and the Sorcerer’s Stone", "Spider-Man", "Finding Nemo",
              "Shrek 2", "Star Wars Ep. III: Revenge of the Sith",
              "Pirates of the Caribbean: Dead Man’s Chest", "Spider-Man 3",
              "The Dark Knight", "Transformers: Revenge of the Fallen", "Toy Story 3"],
    "GENRE": ["Drama", "Adventure", "Adventure", "Adventure",
              "Adventure", "Adventure", "Adventure", "Adventure",
              "Adventure", "Adventure", "Action", "Action", "Adventure",
              "Adventure", "Action", "Action"],
    "juil-21": [259311, 14506, 2251, 81641, 1506, 1296, 7586, 1246,
                544951, 1271, 1246, 5746, 1246, 1246, 908851, 1246],
    "août-21": [263611, 18876, 2286, 86581, 1501, 1296, 7081, 1246,
                576636, 1271, 1246, 5816, 1246, 1246, 953741, 1246],
    "sept-21": [263801, 8641, 2286, 78091, 1501, 1296, 8006, 1246,
                564851, 1271, 1246, 5836, 1246, 1246, 924366, 1246],
    "oct-21": [279256, 5236, 3756, 92076, 1516, 1291, 12296, 1246,
               516416, 1271, 1246, 5671, 1251, 1246, 907576, 1246],
    "nov-21": [283426, 5066, 4451, 94381, 1501, 1296, 1246, 1246,
               558496, 1271, 1246, 5841, 1256, 1246, 945771, 1246],
    "déc-21": [590476, 2286, 4956, 187256, 1746, 1346, 1246, 1246,
               1139066, 1276, 1246, 10066, 1396, 1246, 1928656, 1246],
    "janv-22": [300861, 1316, 2671, 111241, 1496, 1296, 1246, 1246,
                606996, 1246, 1246, 5821, 1256, 1291, 1023031, 1246]
}


# Creating DataFrames
df_part1 = pd.DataFrame(data_part1)


# Display the DataFrames to ensure they are correct
df_part1.head()
# Out:
#                                  MOVIE      GENRE  juil-21  août-21  sept-21  \
# 0                       Batman Forever      Drama   259311   263611   263801
# 1                     Independence Day  Adventure    14506    18876     8641
# 2                         Men in Black  Adventure     2251     2286     2286
# 3                              Titanic  Adventure    81641    86581    78091
# 4  Star Wars Ep. I: The Phantom Menace  Adventure     1506     1501     1501
#
#    oct-21  nov-21  déc-21  janv-22
# 0  279256  283426  590476   300861
# 1    5236    5066    2286     1316
# 2    3756    4451    4956     2671
# 3   92076   94381  187256   111241
# 4    1516    1501    1746     1496

# %%
data = { "juil-21": "",
    "août-21": [ 1246],
    "sept-21": [263801],
    "oct-21": [1246],
    "nov-21": [1246],
    "déc-21": [1246],
    "janv-22": [300861]}

# %%
d= pd.DataFrame(data)

# %%
d
# Out:
#   juil-21  août-21  sept-21  oct-21  nov-21  déc-21  janv-22
# 0             1246   263801    1246    1246    1246   300861
